# %% [markdown]
# # About this notebook
#
# You might have noticed that the train dataset is composed of over 11M data points, but there are only 17k training labels, and 1000k test labels you are predicting. The reason for that is there are many thousand different entries for each `installation_id`, each representing an `event`. This notebook simply gathers all the events into 17k groups, each group corresponds to an `installation_id`. Then, it takes the aggregation (using sums, counts, mean, std, etc.) of those groups, thus resulting in a dataset of summary statistics of each `installation_id`. After that, it simply fits a model on that dataset.
#
# ## Updates
#
# V20:
# * Updated variable names for clarity.
#
# V17:
# * Removed statistics on event codes, since that created a lot of columns and LGBM seems to overfit on that information.
#
# V16:
# * Added mode of title `accuracy_group` (retrieved from training set) as a feature
#
# V10:
# * Fixed labelling problem. Before that, I was blindly predicting the target without even the title I was trying to assess 🤦. I added that now by using the "title" column from `train_labels.csv`, and using the last row of each installation_id from `test.csv` to construct a `test_labels` dataframe.
#
# V8:
# * Added `cv_train`, a function that trains k-models on each of k-fold CV splits. Then, you can use function `cv_predict` to use the list of models to predict an output (and blend the results).
# * Added more summary statistics for `event_code` and `game_time`, including skewness of the distribution.
#
# ## References
#
# * CV idea inspired from [this kernel](https://www.kaggle.com/tanreinama/ds-bowl-2019-simple-lgbm-aggregated-data-with-cv). Thank you!
# * Adding mode as a feature: https://www.kaggle.com/mhviraf/a-baseline-for-dsb-2019

# %%
import os

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#import lightgbm as lgb
import scipy as sp
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report
from sklearn.model_selection import KFold
from tqdm import tqdm

# %%
tqdm.pandas()

# %% [markdown]
# # Load Data

# %%
# %%time
# Only load those columns in order to save space
keep_cols = ['event_id', 'game_session', 'installation_id', 'event_count', 'event_code', 'title', 'game_time', 'type', 'world']

train = pd.read_csv(r'D:\Artificial Intelligence\Kaggle\2019 Data Science Bowl\Data\train.csv')
train_labels = pd.read_csv(r'D:\Artificial Intelligence\Kaggle\2019 Data Science Bowl\Data\train_labels.csv')
spec = pd.read_csv(r'D:\Artificial Intelligence\Kaggle\2019 Data Science Bowl\Data\specs.csv')
    
test = pd.read_csv(r'D:\Artificial Intelligence\Kaggle\2019 Data Science Bowl\Data\test.csv')
submission = pd.read_csv(r'D:\Artificial Intelligence\Kaggle\2019 Data Science Bowl\Data\sample_submission.csv')
# Out:
# Wall time: 48.2 s

# %%
test_assess = test[test.type == 'Assessment'].copy()
test_labels = submission.copy()
test_labels['title'] = test_labels.installation_id.progress_apply(
    lambda install_id: test_assess[test_assess.installation_id == install_id].iloc[-1].title
)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:06<00:00, 157.09it/s]

# %%
test_labels
# Out:
#     installation_id  accuracy_group                         title  title_mode
# 0          00abaee7               3  Cauldron Filler (Assessment)           3
# 1          01242218               3    Cart Balancer (Assessment)           3
# 2          017c5718               3  Mushroom Sorter (Assessment)           3
# 3          01a44906               3  Mushroom Sorter (Assessment)           3
# 4          01bc6cb6               3    Cart Balancer (Assessment)           3
# 5          02256298               3    Cart Balancer (Assessment)           3
# 6          0267757a               3  Mushroom Sorter (Assessment)           3
# 7          027e7ce5               3    Bird Measurer (Assessment)           0
# 8          02a29f99               3     Chest Sorter (Assessment)           0
# 9          0300c576               3    Cart Balancer (Assessment)           3
# 10         03885368               3  Mushroom Sorter (Assessment)           3
# 11         03ac279b               3  Mushroom Sorter (Assessment)           3
# 12         03e33699               3    Cart Balancer (Assessment)           3
# 13         048e7427               3    Cart Balancer (Assessment)           3
# 14         04a7bc3f               3     Chest Sorter (Assessment)           0
# 15         04d31500               3     Chest Sorter (Assessment)           0
# 16         0500e23b               3  Cauldron Filler (Assessment)           3
# 17         0512bf0e               3    Cart Balancer (Assessment)           3
# 18         0525589b               3    Cart Balancer (Assessment)           3
# 19         05488e26               3    Cart Balancer (Assessment)           3
# 20         05771bba               3    Bird Measurer (Assessment)           0
# 21         05b82cf5               3  Mushroom Sorter (Assessment)           3
# 22         05e17e19               3  Cauldron Filler (Assessment)           3
# 23         0617500d               3  Cauldron Filler (Assessment)           3
# 24         068ae11f               3    Bird Measurer (Assessment)           0
# 25         0754f13b               3  Mushroom Sorter (Assessment)           3
# 26         07749e99               3  Cauldron Filler (Assessment)           3
# 27         08611cc8               3  Cauldron Filler (Assessment)           3
# 28         08671ec7               3  Mushroom Sorter (Assessment)           3
# 29         0889b0ae               3  Cauldron Filler (Assessment)           3
# ..              ...             ...                           ...         ...
# 970        f6fb106b               3     Chest Sorter (Assessment)           0
# 971        f7c1b0f3               3    Cart Balancer (Assessment)           3
# 972        f7ec4dd3               3    Bird Measurer (Assessment)           0
# 973        f842b8b3               3    Bird Measurer (Assessment)           0
# 974        f86a6ed4               3  Cauldron Filler (Assessment)           3
# 975        f8d9593e               3    Cart Balancer (Assessment)           3
# 976        f8dacbde               3     Chest Sorter (Assessment)           0
# 977        f99be0ba               3  Cauldron Filler (Assessment)           3
# 978        f9dd0fe3               3  Cauldron Filler (Assessment)           3
# 979        fa21f0e4               3  Mushroom Sorter (Assessment)           3
# 980        fa537c22               3    Cart Balancer (Assessment)           3
# 981        fa845dbf               3    Bird Measurer (Assessment)           0
# 982        faa8c019               3  Mushroom Sorter (Assessment)           3
# 983        faee065f               3  Cauldron Filler (Assessment)           3
# 984        fb3e85f5               3     Chest Sorter (Assessment)           0
# 985        fbe1fea6               3  Cauldron Filler (Assessment)           3
# 986        fc0367c0               3     Chest Sorter (Assessment)           0
# 987        fc5612b9               3  Mushroom Sorter (Assessment)           3
# 988        fca866bc               3     Chest Sorter (Assessment)           0
# 989        fcff43b4               3  Cauldron Filler (Assessment)           3
# 990        fdfed7eb               3  Mushroom Sorter (Assessment)           3
# 991        fe50e0ea               3    Bird Measurer (Assessment)           0
# 992        fe5f7da8               3    Bird Measurer (Assessment)           0
# 993        fe8984b5               3    Bird Measurer (Assessment)           0
# 994        feaa21ac               3  Mushroom Sorter (Assessment)           3
# 995        fee254cf               3  Cauldron Filler (Assessment)           3
# 996        ff57e602               3     Chest Sorter (Assessment)           0
# 997        ffc73fb2               3    Cart Balancer (Assessment)           3
# 998        ffe00ca8               3    Cart Balancer (Assessment)           3
# 999        ffe774cc               3    Bird Measurer (Assessment)           0
#
# [1000 rows x 4 columns]

# %% [markdown]
# # Group and Reduce

# %%
def compute_game_time_stats(group, col):
    return group[
        ['installation_id', col, 'event_count', 'game_time']
    ].groupby(['installation_id', col]).agg(
        [np.mean, np.sum, np.std]
    ).reset_index().pivot(
        columns=col,
        index='installation_id'
    )

# %%
def group_and_reduce(df, df_labels):
    """
    Author: https://www.kaggle.com/xhlulu/
    Source: https://www.kaggle.com/xhlulu/ds-bowl-2019-simple-lgbm-using-aggregated-data
    """
    
    # First only filter the useful part of the df
    df = df[df.installation_id.isin(df_labels.installation_id.unique())]
    
    # group1 is am intermediary "game session" group,
    # which are reduced to one record by game session. group_game_time takes
    # the max value of game_time (final game time in a session) and 
    # of event_count (total number of events happened in the session).
    group_game_time = df.drop(columns=['event_id', 'event_code']).groupby(
        ['game_session', 'installation_id', 'title', 'type', 'world']
    ).max().reset_index()

    # group3, group4 are grouped by installation_id 
    # and reduced using summation and other summary stats
    title_group = (
        pd.get_dummies(
            group_game_time.drop(columns=['game_session', 'event_count', 'game_time']),
            columns=['title', 'type', 'world'])
        .groupby(['installation_id'])
        .sum()
    )

    event_game_time_group = (
        group_game_time[['installation_id', 'event_count', 'game_time']]
        .groupby(['installation_id'])
        .agg([np.sum, np.mean, np.std, np.min, np.max])
    )
    
    # Additional stats on group1
    world_time_stats = compute_game_time_stats(group_game_time, 'world')
    type_time_stats = compute_game_time_stats(group_game_time, 'type')
    
    return (
        title_group.join(event_game_time_group)
        .join(world_time_stats)
        .join(type_time_stats)
        .fillna(0)
    )

# %%
# %%time
train_small = group_and_reduce(train, train_labels)
test_small = group_and_reduce(test, test_labels)

print(train_small.shape)
train_small.head()
# Out:
# C:\Users\srinivasan_b\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:522: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 2 on the right)
#   warnings.warn(msg, UserWarning)
# C:\Users\srinivasan_b\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:522: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 3 on the right)
#   warnings.warn(msg, UserWarning)
# (3614, 110)
# Wall time: 1min 37s
#                  title_12 Monkeys  title_Air Show  title_All Star Sorting  \
# installation_id
# 0006a69f                      2.0             2.0                     4.0
# 0006c192                      1.0             0.0                     0.0
# 00129856                      0.0             0.0                     0.0
# 001d0ed0                      0.0             0.0                     0.0
# 00225f67                      1.0             1.0                     1.0
#
#                  title_Balancing Act  title_Bird Measurer (Assessment)  \
# installation_id
# 0006a69f                         0.0                               2.0
# 0006c192                         2.0                               1.0
# 00129856                         1.0                               1.0
# 001d0ed0                         2.0                               1.0
# 00225f67                         1.0                               1.0
#
#                  title_Bottle Filler (Activity)  title_Bubble Bath  \
# installation_id
# 0006a69f                                    2.0                2.0
# 0006c192                                    1.0                1.0
# 00129856                                    2.0                0.0
# 001d0ed0                                    0.0                0.0
# 00225f67                                    0.0                0.0
#
#                  title_Bug Measurer (Activity)  \
# installation_id
# 0006a69f                                   2.0
# 0006c192                                   1.0
# 00129856                                   2.0
# 001d0ed0                                   0.0
# 00225f67                                   1.0
#
#                  title_Cart Balancer (Assessment)  \
# installation_id
# 0006a69f                                      0.0
# 0006c192                                      0.0
# 00129856                                      0.0
# 001d0ed0                                      2.0
# 00225f67                                      0.0
#
#                  title_Cauldron Filler (Assessment)  ...  \
# installation_id                                      ...
# 0006a69f                                        0.0  ...
# 0006c192                                        2.0  ...
# 00129856                                        0.0  ...
# 001d0ed0                                        0.0  ...
# 00225f67                                        0.0  ...
#
#                  (game_time, mean, Clip)  (game_time, mean, Game)  \
# installation_id
# 0006a69f                             0.0            106966.450000
# 0006c192                             0.0             88345.500000
# 00129856                             0.0                 0.000000
# 001d0ed0                             0.0            158426.166667
# 00225f67                             0.0            129984.750000
#
#                  (game_time, sum, Activity)  (game_time, sum, Assessment)  \
# installation_id
# 0006a69f                          3199695.0                      236429.0
# 0006c192                          1210530.0                      323061.0
# 00129856                          1021179.0                       39742.0
# 001d0ed0                            92282.0                      201941.0
# 00225f67                           294517.0                       35637.0
#
#                  (game_time, sum, Clip)  (game_time, sum, Game)  \
# installation_id
# 0006a69f                            0.0               2139329.0
# 0006c192                            0.0                530073.0
# 00129856                            0.0                     0.0
# 001d0ed0                            0.0                950557.0
# 00225f67                            0.0                519939.0
#
#                  (game_time, std, Activity)  (game_time, std, Assessment)  \
# installation_id
# 0006a69f                      350054.566401                  28330.303185
# 0006c192                      127422.782500                  98940.202632
# 00129856                      130499.803239                  28043.854942
# 001d0ed0                       24694.997226                  17737.374861
# 00225f67                       49028.831364                  12301.536672
#
#                  (game_time, std, Clip)  (game_time, std, Game)
# installation_id
# 0006a69f                            0.0            58189.254197
# 0006c192                            0.0            62500.291205
# 00129856                            0.0                0.000000
# 001d0ed0                            0.0           123969.846618
# 00225f67                            0.0            65432.543128
#
# [5 rows x 110 columns]

# %% [markdown]
# ## Adding mode as feature

# %%
def create_title_mode(train_labels):
    titles = train_labels.title.unique()
    title2mode = {}

    for title in titles:
        mode = (
            train_labels[train_labels.title == title]
            .accuracy_group
            .value_counts()
            .index[0]
        )
        title2mode[title] = mode
    return title2mode

def add_title_mode(labels, title2mode):
    labels['title_mode'] = labels.title.apply(lambda title: title2mode[title])
    return labels

# %%
title2mode = create_title_mode(train_labels)
train_labels = add_title_mode(train_labels, title2mode)
test_labels = add_title_mode(test_labels, title2mode)

# %%
train_labels
# Out:
#            game_session installation_id                         title  \
# 0      6bdf9623adc94d89        0006a69f  Mushroom Sorter (Assessment)
# 1      77b8ee947eb84b4e        0006a69f    Bird Measurer (Assessment)
# 2      901acc108f55a5a1        0006a69f  Mushroom Sorter (Assessment)
# 3      9501794defd84e4d        0006a69f  Mushroom Sorter (Assessment)
# 4      a9ef3ecb3d1acc6a        0006a69f    Bird Measurer (Assessment)
# 5      197a373a77101924        0006c192  Cauldron Filler (Assessment)
# 6      957406a905d59afd        0006c192    Bird Measurer (Assessment)
# 7      b2297d292892745a        0006c192  Mushroom Sorter (Assessment)
# 8      ae691ec5ad5652cf        00129856    Bird Measurer (Assessment)
# 9      7b536271e99518f0        001d0ed0    Bird Measurer (Assessment)
# 10     8fdd5d389d0e272e        001d0ed0     Chest Sorter (Assessment)
# 11     9480b026e3e7d371        001d0ed0    Cart Balancer (Assessment)
# 12     c046a858e7c8bf03        001d0ed0  Mushroom Sorter (Assessment)
# 13     dc6bc0284039c9fb        001d0ed0  Mushroom Sorter (Assessment)
# 14     619b9c069cf790ca        00225f67    Bird Measurer (Assessment)
# 15     346d5f57cf40bac0        00279ac5     Chest Sorter (Assessment)
# 16     03e73cfb40d8d204        002db7e3  Mushroom Sorter (Assessment)
# 17     113a557b60770369        002db7e3    Cart Balancer (Assessment)
# 18     1c48bdca76efc7b0        002db7e3  Mushroom Sorter (Assessment)
# 19     470a1bd6b99152a7        002db7e3  Cauldron Filler (Assessment)
# 20     5025f22d6e944533        002db7e3    Bird Measurer (Assessment)
# 21     67f9274eb736ab3f        002db7e3     Chest Sorter (Assessment)
# 22     8f50f2fd987cade4        002db7e3    Bird Measurer (Assessment)
# 23     cace4c493ac347e3        002db7e3    Bird Measurer (Assessment)
# 24     f50104895c55045f        002db7e3     Chest Sorter (Assessment)
# 25     0adc585fb4f48458        003372b0    Cart Balancer (Assessment)
# 26     272cc78535e9add1        003372b0  Cauldron Filler (Assessment)
# 27     28113cd58d865372        003372b0    Bird Measurer (Assessment)
# 28     3beae5a17e0b26f6        003372b0    Cart Balancer (Assessment)
# 29     4649b29840d5b0f1        003372b0     Chest Sorter (Assessment)
# ...                 ...             ...                           ...
# 17660  0b2c8152e8a59f3e        ff90db99    Cart Balancer (Assessment)
# 17661  1eb3dda21a7d0d22        ff90db99     Chest Sorter (Assessment)
# 17662  2ba76e51acd87d41        ff90db99    Bird Measurer (Assessment)
# 17663  6e4bc0827f95aa1d        ff90db99  Mushroom Sorter (Assessment)
# 17664  86bc6380bcf6318a        ff90db99    Cart Balancer (Assessment)
# 17665  92c0b831c575d0a2        ff90db99     Chest Sorter (Assessment)
# 17666  d1eb504ea2bff895        ff90db99  Cauldron Filler (Assessment)
# 17667  78afb1f178333a91        ff9305d7    Bird Measurer (Assessment)
# 17668  967f050913e025e7        ff9305d7    Bird Measurer (Assessment)
# 17669  ac14ae89afa373c0        ff9305d7     Chest Sorter (Assessment)
# 17670  c19e33a37f4750ba        ff9305d7     Chest Sorter (Assessment)
# 17671  0b88b87b9a639bec        ff9715db  Mushroom Sorter (Assessment)
# 17672  4767c079c810f31b        ff9715db    Cart Balancer (Assessment)
# 17673  644f61ee30ce39f6        ff9715db  Mushroom Sorter (Assessment)
# 17674  7a2ceddb020f9fb9        ff9715db     Chest Sorter (Assessment)
# 17675  91053d5451056830        ff9715db    Cart Balancer (Assessment)
# 17676  f2957d390e318bea        ff9715db     Chest Sorter (Assessment)
# 17677  f2bca2036a9ec41b        ff9715db  Mushroom Sorter (Assessment)
# 17678  f31a63e827e0b6c0        ff9715db    Cart Balancer (Assessment)
# 17679  fad7b5cfd31171a0        ff9715db  Cauldron Filler (Assessment)
# 17680  14de9db5ad7dd503        ffc90c32    Cart Balancer (Assessment)
# 17681  460e8bdc2822b340        ffc90c32     Chest Sorter (Assessment)
# 17682  7028e68b20c5f586        ffc90c32  Cauldron Filler (Assessment)
# 17683  8f59b0b22325ef96        ffc90c32  Mushroom Sorter (Assessment)
# 17684  98e91ee8ce88793b        ffc90c32  Mushroom Sorter (Assessment)
# 17685  c996482b11d149dd        ffc90c32    Bird Measurer (Assessment)
# 17686  b05a02b52d5c1f4c        ffd2871d  Cauldron Filler (Assessment)
# 17687  5448d652309a6324        ffeb0b1b  Cauldron Filler (Assessment)
# 17688  a6885ab824fbc32c        ffeb0b1b  Mushroom Sorter (Assessment)
# 17689  dadd1a4d8ac68ab0        ffeb0b1b  Cauldron Filler (Assessment)
#
#        num_correct  num_incorrect  accuracy  accuracy_group  title_mode
# 0                1              0  1.000000               3           3
# 1                0             11  0.000000               0           0
# 2                1              0  1.000000               3           3
# 3                1              1  0.500000               2           3
# 4                1              0  1.000000               3           0
# 5                1              0  1.000000               3           3
# 6                1              1  0.500000               2           0
# 7                0              4  0.000000               0           3
# 8                1              0  1.000000               3           0
# 9                0              5  0.000000               0           0
# 10               0              1  0.000000               0           0
# 11               1              0  1.000000               3           3
# 12               1              1  0.500000               2           3
# 13               1              0  1.000000               3           3
# 14               0              2  0.000000               0           0
# 15               0             11  0.000000               0           0
# 16               1              1  0.500000               2           3
# 17               1              0  1.000000               3           3
# 18               1              0  1.000000               3           3
# 19               1              0  1.000000               3           3
# 20               1              4  0.200000               1           0
# 21               0              5  0.000000               0           0
# 22               1              1  0.500000               2           0
# 23               1             10  0.090909               1           0
# 24               0              7  0.000000               0           0
# 25               1              0  1.000000               3           3
# 26               1              0  1.000000               3           3
# 27               1              1  0.500000               2           0
# 28               1              0  1.000000               3           3
# 29               0              4  0.000000               0           0
# ...            ...            ...       ...             ...         ...
# 17660            1              0  1.000000               3           3
# 17661            1              0  1.000000               3           0
# 17662            1              2  0.333333               1           0
# 17663            1              0  1.000000               3           3
# 17664            1              0  1.000000               3           3
# 17665            1              0  1.000000               3           0
# 17666            1              0  1.000000               3           3
# 17667            1             12  0.076923               1           0
# 17668            1              3  0.250000               1           0
# 17669            0              3  0.000000               0           0
# 17670            0              3  0.000000               0           0
# 17671            1              0  1.000000               3           3
# 17672            1              0  1.000000               3           3
# 17673            1              0  1.000000               3           3
# 17674            1              3  0.250000               1           0
# 17675            1              0  1.000000               3           3
# 17676            1              1  0.500000               2           0
# 17677            1              0  1.000000               3           3
# 17678            0              6  0.000000               0           3
# 17679            1              0  1.000000               3           3
# 17680            1              0  1.000000               3           3
# 17681            1              0  1.000000               3           0
# 17682            1              0  1.000000               3           3
# 17683            1              0  1.000000               3           3
# 17684            1              2  0.333333               1           3
# 17685            1              0  1.000000               3           0
# 17686            1              0  1.000000               3           3
# 17687            1              2  0.333333               1           3
# 17688            0              1  0.000000               0           3
# 17689            1              2  0.333333               1           3
#
# [17690 rows x 8 columns]

# %%
title2mode
# Out:
# {'Mushroom Sorter (Assessment)': 3,
#  'Bird Measurer (Assessment)': 0,
#  'Cauldron Filler (Assessment)': 3,
#  'Chest Sorter (Assessment)': 0,
#  'Cart Balancer (Assessment)': 3}

# %% [markdown]
# ## Combine train/test labels with summary stats

# %%
def preprocess_train(train_labels, last_records_only=True):
    """
    last_records_only (bool): Use only the last record of each user.
    """
    final_train = pd.get_dummies(
        (
            train_labels.set_index('installation_id')
            .drop(columns=['num_correct', 'num_incorrect', 'accuracy', 'game_session'])
            .join(train_small)
        ), 
        columns=['title']
    )
    
    if last_records_only:
        final_train = (
            final_train
            .reset_index()
            .groupby('installation_id')
            .apply(lambda x: x.iloc[-1])
            .drop(columns='installation_id')
        )
    
    return final_train

def preprocess_test(test_labels, test_small):
    return pd.get_dummies(
        test_labels.set_index('installation_id').join(test_small), columns=['title']
    )

# %%
final_train = preprocess_train(train_labels)
print(final_train.shape)
final_train.head()
# Out:
# (3614, 117)
#                  accuracy_group  title_mode  title_12 Monkeys  title_Air Show  \
# installation_id
# 0006a69f                      3           0               2.0             2.0
# 0006c192                      0           3               1.0             0.0
# 00129856                      3           0               0.0             0.0
# 001d0ed0                      3           3               0.0             0.0
# 00225f67                      0           0               1.0             1.0
#
#                  title_All Star Sorting  title_Balancing Act  \
# installation_id
# 0006a69f                            4.0                  0.0
# 0006c192                            0.0                  2.0
# 00129856                            0.0                  1.0
# 001d0ed0                            0.0                  2.0
# 00225f67                            1.0                  1.0
#
#                  title_Bird Measurer (Assessment)  \
# installation_id
# 0006a69f                                      2.0
# 0006c192                                      1.0
# 00129856                                      1.0
# 001d0ed0                                      1.0
# 00225f67                                      1.0
#
#                  title_Bottle Filler (Activity)  title_Bubble Bath  \
# installation_id
# 0006a69f                                    2.0                2.0
# 0006c192                                    1.0                1.0
# 00129856                                    2.0                0.0
# 001d0ed0                                    0.0                0.0
# 00225f67                                    0.0                0.0
#
#                  title_Bug Measurer (Activity)  ...  (game_time, sum, Game)  \
# installation_id                                 ...
# 0006a69f                                   2.0  ...               2139329.0
# 0006c192                                   1.0  ...                530073.0
# 00129856                                   2.0  ...                     0.0
# 001d0ed0                                   0.0  ...                950557.0
# 00225f67                                   1.0  ...                519939.0
#
#                  (game_time, std, Activity)  (game_time, std, Assessment)  \
# installation_id
# 0006a69f                      350054.566401                  28330.303185
# 0006c192                      127422.782500                  98940.202632
# 00129856                      130499.803239                  28043.854942
# 001d0ed0                       24694.997226                  17737.374861
# 00225f67                       49028.831364                  12301.536672
#
#                  (game_time, std, Clip)  (game_time, std, Game)  \
# installation_id
# 0006a69f                            0.0            58189.254197
# 0006c192                            0.0            62500.291205
# 00129856                            0.0                0.000000
# 001d0ed0                            0.0           123969.846618
# 00225f67                            0.0            65432.543128
#
#                  title_Bird Measurer (Assessment)  \
# installation_id
# 0006a69f                                        1
# 0006c192                                        0
# 00129856                                        1
# 001d0ed0                                        0
# 00225f67                                        1
#
#                  title_Cart Balancer (Assessment)  \
# installation_id
# 0006a69f                                        0
# 0006c192                                        0
# 00129856                                        0
# 001d0ed0                                        0
# 00225f67                                        0
#
#                  title_Cauldron Filler (Assessment)  \
# installation_id
# 0006a69f                                          0
# 0006c192                                          0
# 00129856                                          0
# 001d0ed0                                          0
# 00225f67                                          0
#
#                  title_Chest Sorter (Assessment)  \
# installation_id
# 0006a69f                                       0
# 0006c192                                       0
# 00129856                                       0
# 001d0ed0                                       0
# 00225f67                                       0
#
#                  title_Mushroom Sorter (Assessment)
# installation_id
# 0006a69f                                          0
# 0006c192                                          1
# 00129856                                          0
# 001d0ed0                                          1
# 00225f67                                          0
#
# [5 rows x 117 columns]

# %%
final_test = preprocess_test(test_labels, test_small)
print(final_test.shape)
final_test.head()
# Out:
# (1000, 117)
#                  accuracy_group  title_mode  title_12 Monkeys  title_Air Show  \
# installation_id
# 00abaee7                      3           3               2.0             0.0
# 01242218                      3           3               1.0             1.0
# 017c5718                      3           3               0.0             0.0
# 01a44906                      3           3               1.0             0.0
# 01bc6cb6                      3           3               0.0             0.0
#
#                  title_All Star Sorting  title_Balancing Act  \
# installation_id
# 00abaee7                            1.0                  1.0
# 01242218                            1.0                  3.0
# 017c5718                            0.0                  0.0
# 01a44906                            1.0                  0.0
# 01bc6cb6                            3.0                  1.0
#
#                  title_Bird Measurer (Assessment)  \
# installation_id
# 00abaee7                                      0.0
# 01242218                                      1.0
# 017c5718                                      0.0
# 01a44906                                      0.0
# 01bc6cb6                                      0.0
#
#                  title_Bottle Filler (Activity)  title_Bubble Bath  \
# installation_id
# 00abaee7                                    0.0                0.0
# 01242218                                    2.0                1.0
# 017c5718                                    0.0                0.0
# 01a44906                                    0.0                0.0
# 01bc6cb6                                    0.0                0.0
#
#                  title_Bug Measurer (Activity)  ...  (game_time, sum, Game)  \
# installation_id                                 ...
# 00abaee7                                   2.0  ...               2285229.0
# 01242218                                   1.0  ...               1420909.0
# 017c5718                                   0.0  ...                     0.0
# 01a44906                                   0.0  ...                 77204.0
# 01bc6cb6                                   0.0  ...                984880.0
#
#                  (game_time, std, Activity)  (game_time, std, Assessment)  \
# installation_id
# 00abaee7                       36886.664956                  21240.073493
# 01242218                       98521.245018                  32761.743006
# 017c5718                        6389.416875                      0.000000
# 01a44906                       43064.217188                      0.000000
# 01bc6cb6                           0.000000                      0.000000
#
#                  (game_time, std, Clip)  (game_time, std, Game)  \
# installation_id
# 00abaee7                            0.0            1.038605e+06
# 01242218                            0.0            3.779781e+04
# 017c5718                            0.0            0.000000e+00
# 01a44906                            0.0            0.000000e+00
# 01bc6cb6                            0.0            1.780426e+05
#
#                  title_Bird Measurer (Assessment)  \
# installation_id
# 00abaee7                                        0
# 01242218                                        0
# 017c5718                                        0
# 01a44906                                        0
# 01bc6cb6                                        0
#
#                  title_Cart Balancer (Assessment)  \
# installation_id
# 00abaee7                                        0
# 01242218                                        1
# 017c5718                                        0
# 01a44906                                        0
# 01bc6cb6                                        1
#
#                  title_Cauldron Filler (Assessment)  \
# installation_id
# 00abaee7                                          1
# 01242218                                          0
# 017c5718                                          0
# 01a44906                                          0
# 01bc6cb6                                          0
#
#                  title_Chest Sorter (Assessment)  \
# installation_id
# 00abaee7                                       0
# 01242218                                       0
# 017c5718                                       0
# 01a44906                                       0
# 01bc6cb6                                       0
#
#                  title_Mushroom Sorter (Assessment)
# installation_id
# 00abaee7                                          0
# 01242218                                          0
# 017c5718                                          1
# 01a44906                                          1
# 01bc6cb6                                          0
#
# [5 rows x 117 columns]

# %% [markdown]
# # Training model

# %%
def cv_train(X, y, cv, **kwargs):
    """
    Author: https://www.kaggle.com/xhlulu/
    Source: https://www.kaggle.com/xhlulu/ds-bowl-2019-simple-lgbm-using-aggregated-data
    """
    models = []
    
    kf = KFold(n_splits=cv, random_state=2019)
    
    for train, test in kf.split(X):
        x_train, x_val, y_train, y_val = X[train], X[test], y[train], y[test]
        
        train_set = lgb.Dataset(x_train, y_train)
        val_set = lgb.Dataset(x_val, y_val)
        
        model = lgb.train(train_set=train_set, valid_sets=[train_set, val_set], **kwargs)
        models.append(model)
        
        if kwargs.get("verbose_eval"):
            print("\n" + "="*50 + "\n")
    
    return models

def cv_predict(models, X):
    return np.mean([model.predict(X) for model in models], axis=0)

# %%
train[train['installation_id'].isin(['0006c192']) ]
# Out:
#       event_id      game_session                 timestamp  \
# 5339  27253bdc  3e3ac29e618b6f0a  2019-09-13T00:30:24.242Z
# 5340  27253bdc  2be846a18a653f7c  2019-09-13T00:30:51.223Z
# 5341  7d093bf9  e6a6a262a8243ff7  2019-09-13T00:31:20.165Z
# 5342  f93fc684  e6a6a262a8243ff7  2019-09-13T00:31:22.262Z
# 5343  7ec0c298  e6a6a262a8243ff7  2019-09-13T00:31:24.467Z
# 5344  0d1da71f  e6a6a262a8243ff7  2019-09-13T00:31:30.572Z
# 5345  63f13dd7  e6a6a262a8243ff7  2019-09-13T00:31:30.573Z
# 5346  7372e1a5  e6a6a262a8243ff7  2019-09-13T00:31:30.680Z
# 5347  7372e1a5  e6a6a262a8243ff7  2019-09-13T00:31:30.982Z
# 5348  7372e1a5  e6a6a262a8243ff7  2019-09-13T00:31:32.216Z
# 5349  7372e1a5  e6a6a262a8243ff7  2019-09-13T00:31:32.549Z
# 5350  7372e1a5  e6a6a262a8243ff7  2019-09-13T00:31:32.882Z
# 5351  7372e1a5  e6a6a262a8243ff7  2019-09-13T00:31:33.582Z
# 5352  7372e1a5  e6a6a262a8243ff7  2019-09-13T00:31:33.946Z
# 5353  cfbd47c8  e6a6a262a8243ff7  2019-09-13T00:31:34.549Z
# 5354  d185d3ea  e6a6a262a8243ff7  2019-09-13T00:31:34.661Z
# 5355  7372e1a5  e6a6a262a8243ff7  2019-09-13T00:31:35.032Z
# 5356  cfbd47c8  e6a6a262a8243ff7  2019-09-13T00:31:36.065Z
# 5357  4ef8cdd3  e6a6a262a8243ff7  2019-09-13T00:31:36.645Z
# 5358  7372e1a5  e6a6a262a8243ff7  2019-09-13T00:31:37.428Z
# 5359  7372e1a5  e6a6a262a8243ff7  2019-09-13T00:31:37.428Z
# 5360  0330ab6a  e6a6a262a8243ff7  2019-09-13T00:31:37.696Z
# 5361  cfbd47c8  e6a6a262a8243ff7  2019-09-13T00:31:38.114Z
# 5362  4ef8cdd3  e6a6a262a8243ff7  2019-09-13T00:31:39.046Z
# 5363  7372e1a5  e6a6a262a8243ff7  2019-09-13T00:31:39.801Z
# 5364  2230fab4  e6a6a262a8243ff7  2019-09-13T00:31:40.098Z
# 5365  0330ab6a  e6a6a262a8243ff7  2019-09-13T00:31:40.098Z
# 5366  cfbd47c8  e6a6a262a8243ff7  2019-09-13T00:31:41.349Z
# 5367  4ef8cdd3  e6a6a262a8243ff7  2019-09-13T00:31:42.194Z
# 5368  0330ab6a  e6a6a262a8243ff7  2019-09-13T00:31:42.630Z
# ...        ...               ...                       ...
# 7533  8fee50e2  957406a905d59afd  2019-10-01T01:02:30.062Z
# 7534  51102b85  957406a905d59afd  2019-10-01T01:02:30.213Z
# 7535  8fee50e2  957406a905d59afd  2019-10-01T01:02:30.278Z
# 7536  51102b85  957406a905d59afd  2019-10-01T01:02:30.414Z
# 7537  8fee50e2  957406a905d59afd  2019-10-01T01:02:30.496Z
# 7538  a16a373e  957406a905d59afd  2019-10-01T01:02:30.801Z
# 7539  a16a373e  957406a905d59afd  2019-10-01T01:02:30.989Z
# 7540  a16a373e  957406a905d59afd  2019-10-01T01:02:31.220Z
# 7541  a16a373e  957406a905d59afd  2019-10-01T01:02:31.460Z
# 7542  bdf49a58  957406a905d59afd  2019-10-01T01:02:31.987Z
# 7543  a16a373e  957406a905d59afd  2019-10-01T01:02:32.211Z
# 7544  a16a373e  957406a905d59afd  2019-10-01T01:02:32.474Z
# 7545  a16a373e  957406a905d59afd  2019-10-01T01:02:32.755Z
# 7546  a16a373e  957406a905d59afd  2019-10-01T01:02:33.006Z
# 7547  a16a373e  957406a905d59afd  2019-10-01T01:02:33.292Z
# 7548  a16a373e  957406a905d59afd  2019-10-01T01:02:33.559Z
# 7549  a16a373e  957406a905d59afd  2019-10-01T01:02:33.841Z
# 7550  a16a373e  957406a905d59afd  2019-10-01T01:02:34.161Z
# 7551  a16a373e  957406a905d59afd  2019-10-01T01:02:34.858Z
# 7552  a16a373e  957406a905d59afd  2019-10-01T01:02:36.842Z
# 7553  a16a373e  957406a905d59afd  2019-10-01T01:02:37.177Z
# 7554  a16a373e  957406a905d59afd  2019-10-01T01:02:39.740Z
# 7555  a16a373e  957406a905d59afd  2019-10-01T01:02:45.398Z
# 7556  a16a373e  957406a905d59afd  2019-10-01T01:02:45.746Z
# 7557  a16a373e  957406a905d59afd  2019-10-01T01:02:45.923Z
# 7558  a16a373e  957406a905d59afd  2019-10-01T01:02:46.141Z
# 7559  a16a373e  957406a905d59afd  2019-10-01T01:02:46.288Z
# 7560  a16a373e  957406a905d59afd  2019-10-01T01:02:46.523Z
# 7561  27253bdc  b707bf03764bb64e  2019-10-01T01:03:33.542Z
# 7562  27253bdc  df16e87c1003851d  2019-10-01T01:04:36.492Z
#
#                                              event_data installation_id  \
# 5339             {"event_code": 2000, "event_count": 1}        0006c192
# 5340             {"event_code": 2000, "event_count": 1}        0006c192
# 5341  {"version":"1.0","round":0,"event_count":1,"ga...        0006c192
# 5342  {"coordinates":{"x":452,"y":680,"stage_width":...        0006c192
# 5343  {"description":"It's Chow Time! We have some V...        0006c192
# 5344  {"description":"It's Chow Time! We have some V...        0006c192
# 5345  {"dinosaur":"buddy","diet":"carnivore","target...        0006c192
# 5346  {"coordinates":{"x":970,"y":360,"stage_width":...        0006c192
# 5347  {"coordinates":{"x":984,"y":371,"stage_width":...        0006c192
# 5348  {"coordinates":{"x":319,"y":306,"stage_width":...        0006c192
# 5349  {"coordinates":{"x":299,"y":324,"stage_width":...        0006c192
# 5350  {"coordinates":{"x":299,"y":344,"stage_width":...        0006c192
# 5351  {"coordinates":{"x":347,"y":327,"stage_width":...        0006c192
# 5352  {"coordinates":{"x":350,"y":308,"stage_width":...        0006c192
# 5353  {"weight":1,"source":"resources","resources":[...        0006c192
# 5354  {"weight":1,"resources":[3,3,1],"coordinates":...        0006c192
# 5355  {"coordinates":{"x":277,"y":686,"stage_width":...        0006c192
# 5356  {"weight":3,"source":"resources","resources":[...        0006c192
# 5357  {"weight":3,"correct":true,"scale_weight":3,"s...        0006c192
# 5358  {"coordinates":{"x":202,"y":380,"stage_width":...        0006c192
# 5359  {"coordinates":{"x":612,"y":726,"stage_width":...        0006c192
# 5360  {"description":"That's not enough food. Try pu...        0006c192
# 5361  {"weight":3,"source":"resources","resources":[...        0006c192
# 5362  {"weight":3,"correct":false,"scale_weight":6,"...        0006c192
# 5363  {"coordinates":{"x":343,"y":696,"stage_width":...        0006c192
# 5364  {"description":"That's not enough food. Try pu...        0006c192
# 5365  {"description":"That's too much food. Try taki...        0006c192
# 5366  {"weight":1,"source":"resources","resources":[...        0006c192
# 5367  {"weight":1,"correct":false,"scale_weight":7,"...        0006c192
# 5368  {"description":"That's too much food. Try taki...        0006c192
# ...                                                 ...             ...
# 7533  {"hat":8,"destination":"middle","coordinates":...        0006c192
# 7534  {"hat":8,"caterpillar":"","coordinates":{"x":5...        0006c192
# 7535  {"hat":8,"destination":"middle","coordinates":...        0006c192
# 7536  {"hat":8,"caterpillar":"","coordinates":{"x":5...        0006c192
# 7537  {"hat":8,"destination":"middle","coordinates":...        0006c192
# 7538  {"coordinates":{"x":535,"y":87,"stage_width":1...        0006c192
# 7539  {"coordinates":{"x":560,"y":106,"stage_width":...        0006c192
# 7540  {"coordinates":{"x":557,"y":93,"stage_width":1...        0006c192
# 7541  {"coordinates":{"x":570,"y":74,"stage_width":1...        0006c192
# 7542  {"description":"When you want to check to see ...        0006c192
# 7543  {"coordinates":{"x":505,"y":128,"stage_width":...        0006c192
# 7544  {"coordinates":{"x":508,"y":94,"stage_width":1...        0006c192
# 7545  {"coordinates":{"x":556,"y":96,"stage_width":1...        0006c192
# 7546  {"coordinates":{"x":596,"y":88,"stage_width":1...        0006c192
# 7547  {"coordinates":{"x":578,"y":104,"stage_width":...        0006c192
# 7548  {"coordinates":{"x":537,"y":78,"stage_width":1...        0006c192
# 7549  {"coordinates":{"x":542,"y":94,"stage_width":1...        0006c192
# 7550  {"coordinates":{"x":510,"y":35,"stage_width":1...        0006c192
# 7551  {"coordinates":{"x":234,"y":55,"stage_width":1...        0006c192
# 7552  {"coordinates":{"x":550,"y":84,"stage_width":1...        0006c192
# 7553  {"coordinates":{"x":493,"y":26,"stage_width":1...        0006c192
# 7554  {"coordinates":{"x":56,"y":84,"stage_width":10...        0006c192
# 7555  {"coordinates":{"x":500,"y":522,"stage_width":...        0006c192
# 7556  {"coordinates":{"x":541,"y":99,"stage_width":1...        0006c192
# 7557  {"coordinates":{"x":557,"y":105,"stage_width":...        0006c192
# 7558  {"coordinates":{"x":534,"y":112,"stage_width":...        0006c192
# 7559  {"coordinates":{"x":530,"y":91,"stage_width":1...        0006c192
# 7560  {"coordinates":{"x":533,"y":74,"stage_width":1...        0006c192
# 7561             {"event_code": 2000, "event_count": 1}        0006c192
# 7562             {"event_code": 2000, "event_count": 1}        0006c192
#
#       event_count  event_code  game_time                       title  \
# 5339            1        2000          0     Welcome to Lost Lagoon!
# 5340            1        2000          0     Crystal Caves - Level 1
# 5341            1        2000          0                   Chow Time
# 5342            2        4010       2157                   Chow Time
# 5343            3        3010       4351                   Chow Time
# 5344            4        3110      10434                   Chow Time
# 5345            5        2020      10434                   Chow Time
# 5346            6        4070      10568                   Chow Time
# 5347            7        4070      10868                   Chow Time
# 5348            8        4070      12103                   Chow Time
# 5349            9        4070      12435                   Chow Time
# 5350           10        4070      12768                   Chow Time
# 5351           11        4070      13468                   Chow Time
# 5352           12        4070      13835                   Chow Time
# 5353           13        4030      14435                   Chow Time
# 5354           14        4035      14553                   Chow Time
# 5355           15        4070      14918                   Chow Time
# 5356           16        4030      15952                   Chow Time
# 5357           17        4020      16536                   Chow Time
# 5358           19        4070      17319                   Chow Time
# 5359           18        4070      17319                   Chow Time
# 5360           20        3020      17586                   Chow Time
# 5361           21        4030      18002                   Chow Time
# 5362           22        4020      18936                   Chow Time
# 5363           23        4070      19685                   Chow Time
# 5364           24        3120      19987                   Chow Time
# 5365           25        3020      19987                   Chow Time
# 5366           26        4030      21235                   Chow Time
# 5367           27        4020      22085                   Chow Time
# 5368           29        3020      22519                   Chow Time
# ...           ...         ...        ...                         ...
# 7533          173        4020     199923  Bird Measurer (Assessment)
# 7534          174        4030     200057  Bird Measurer (Assessment)
# 7535          175        4020     200140  Bird Measurer (Assessment)
# 7536          176        4030     200257  Bird Measurer (Assessment)
# 7537          177        4020     200357  Bird Measurer (Assessment)
# 7538          178        4070     200640  Bird Measurer (Assessment)
# 7539          179        4070     200840  Bird Measurer (Assessment)
# 7540          180        4070     201073  Bird Measurer (Assessment)
# 7541          181        4070     201308  Bird Measurer (Assessment)
# 7542          182        3110     201857  Bird Measurer (Assessment)
# 7543          183        4070     202057  Bird Measurer (Assessment)
# 7544          184        4070     202323  Bird Measurer (Assessment)
# 7545          185        4070     202607  Bird Measurer (Assessment)
# 7546          186        4070     202857  Bird Measurer (Assessment)
# 7547          187        4070     203140  Bird Measurer (Assessment)
# 7548          188        4070     203407  Bird Measurer (Assessment)
# 7549          189        4070     203690  Bird Measurer (Assessment)
# 7550          190        4070     204007  Bird Measurer (Assessment)
# 7551          191        4070     204707  Bird Measurer (Assessment)
# 7552          192        4070     206690  Bird Measurer (Assessment)
# 7553          193        4070     207024  Bird Measurer (Assessment)
# 7554          194        4070     209591  Bird Measurer (Assessment)
# 7555          195        4070     215241  Bird Measurer (Assessment)
# 7556          196        4070     215591  Bird Measurer (Assessment)
# 7557          197        4070     215774  Bird Measurer (Assessment)
# 7558          198        4070     215991  Bird Measurer (Assessment)
# 7559          199        4070     216141  Bird Measurer (Assessment)
# 7560          200        4070     216374  Bird Measurer (Assessment)
# 7561            1        2000          0     Tree Top City - Level 3
# 7562            1        2000          0     Crystal Caves - Level 2
#
#             type         world
# 5339        Clip          NONE
# 5340        Clip  CRYSTALCAVES
# 5341        Game  CRYSTALCAVES
# 5342        Game  CRYSTALCAVES
# 5343        Game  CRYSTALCAVES
# 5344        Game  CRYSTALCAVES
# 5345        Game  CRYSTALCAVES
# 5346        Game  CRYSTALCAVES
# 5347        Game  CRYSTALCAVES
# 5348        Game  CRYSTALCAVES
# 5349        Game  CRYSTALCAVES
# 5350        Game  CRYSTALCAVES
# 5351        Game  CRYSTALCAVES
# 5352        Game  CRYSTALCAVES
# 5353        Game  CRYSTALCAVES
# 5354        Game  CRYSTALCAVES
# 5355        Game  CRYSTALCAVES
# 5356        Game  CRYSTALCAVES
# 5357        Game  CRYSTALCAVES
# 5358        Game  CRYSTALCAVES
# 5359        Game  CRYSTALCAVES
# 5360        Game  CRYSTALCAVES
# 5361        Game  CRYSTALCAVES
# 5362        Game  CRYSTALCAVES
# 5363        Game  CRYSTALCAVES
# 5364        Game  CRYSTALCAVES
# 5365        Game  CRYSTALCAVES
# 5366        Game  CRYSTALCAVES
# 5367        Game  CRYSTALCAVES
# 5368        Game  CRYSTALCAVES
# ...          ...           ...
# 7533  Assessment   TREETOPCITY
# 7534  Assessment   TREETOPCITY
# 7535  Assessment   TREETOPCITY
# 7536  Assessment   TREETOPCITY
# 7537  Assessment   TREETOPCITY
# 7538  Assessment   TREETOPCITY
# 7539  Assessment   TREETOPCITY
# 7540  Assessment   TREETOPCITY
# 7541  Assessment   TREETOPCITY
# 7542  Assessment   TREETOPCITY
# 7543  Assessment   TREETOPCITY
# 7544  Assessment   TREETOPCITY
# 7545  Assessment   TREETOPCITY
# 7546  Assessment   TREETOPCITY
# 7547  Assessment   TREETOPCITY
# 7548  Assessment   TREETOPCITY
# 7549  Assessment   TREETOPCITY
# 7550  Assessment   TREETOPCITY
# 7551  Assessment   TREETOPCITY
# 7552  Assessment   TREETOPCITY
# 7553  Assessment   TREETOPCITY
# 7554  Assessment   TREETOPCITY
# 7555  Assessment   TREETOPCITY
# 7556  Assessment   TREETOPCITY
# 7557  Assessment   TREETOPCITY
# 7558  Assessment   TREETOPCITY
# 7559  Assessment   TREETOPCITY
# 7560  Assessment   TREETOPCITY
# 7561        Clip   TREETOPCITY
# 7562        Clip  CRYSTALCAVES
#
# [2224 rows x 11 columns]

# %%
train_labels[train_labels['installation_id'].isin(['0006c192']) ]
# Out:
#        game_session installation_id                         title  \
# 5  197a373a77101924        0006c192  Cauldron Filler (Assessment)
# 6  957406a905d59afd        0006c192    Bird Measurer (Assessment)
# 7  b2297d292892745a        0006c192  Mushroom Sorter (Assessment)
#
#    num_correct  num_incorrect  accuracy  accuracy_group  title_mode
# 5            1              0       1.0               3           3
# 6            1              1       0.5               2           0
# 7            0              4       0.0               0           3

# %%
X_old = final_train


final_train['accuracy_group']
# Out:
# installation_id
# 0006a69f    3
# 0006c192    0
# 00129856    3
# 001d0ed0    3
# 00225f67    0
# 00279ac5    0
# 002db7e3    0
# 003372b0    3
# 004c2091    3
# 00634433    0
# 00667b88    3
# 00691033    0
# 00a0dbeb    0
# 00a53963    3
# 00ad158e    1
# 00b9d8e6    2
# 00cef781    3
# 00e17272    3
# 00e536bf    3
# 00fa8681    3
# 00fc65b6    1
# 010bc1d5    3
# 01120f12    0
# 0153c957    0
# 0155dd86    0
# 015776b4    0
# 01582211    0
# 0160e7c5    1
# 01825124    1
# 01bdd720    0
#            ..
# fd6e3ad6    3
# fd8ee8db    3
# fd97b5b2    0
# fd997268    3
# fd99b7b3    3
# fdd082f9    0
# fddf4b1e    3
# fdf4eb95    3
# fe191c4a    2
# fe1a1d3f    3
# fe488283    1
# fe4a63a7    3
# fe4d880a    0
# fe5f0699    0
# fe73bf4b    1
# fe769df4    1
# fe9f9b60    0
# fed331e8    3
# ff00d909    3
# ff107709    2
# ff24ea49    3
# ff3e1e35    0
# ff7fb595    3
# ff882868    3
# ff90db99    3
# ff9305d7    0
# ff9715db    3
# ffc90c32    3
# ffd2871d    3
# ffeb0b1b    1
# Name: accuracy_group, Length: 3614, dtype: int64

# %%
X = final_train.drop(columns='accuracy_group').values
y = final_train['accuracy_group'].values

# %%
params = {
    'learning_rate': 0.01,
    'bagging_fraction': 0.9,
    'feature_fraction': 0.2,
    'max_height': 3,
    'lambda_l1': 10,
    'lambda_l2': 10,
    'metric': 'multiclass',
    'objective': 'multiclass',
    'num_classes': 4,
    'random_state': 2019
}

models = cv_train(X, y, cv=20, params=params, num_boost_round=1000,
                  early_stopping_rounds=100, verbose_eval=500)

# %% [markdown]
# # Submission

# %%
X_test = final_test.drop(columns=['accuracy_group'])
test_pred = cv_predict(models=models, X=X_test).argmax(axis=1)

final_test['accuracy_group'] = test_pred
final_test[['accuracy_group']].to_csv('submission.csv')

# %% [markdown]
# # Visualize Model

# %%
for model in models:
    lgb.plot_importance(model, max_num_features=15, height=0.3)

# %%
plt.hist(test_pred)
